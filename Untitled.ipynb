# %% [markdown]
# # This was essentialy just a playground for me to learn pandas and matplotlib. There's no rhyme or rythymn to anything below, nor have I answered any question.

# %% [markdown]
# #

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read the dataset and show Headers

# %%
data = pd.read_csv("renfe.csv")
print(data.head())
# Out:
#    Unnamed: 0          insert_date  origin destination           start_date  \
# 0           0  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 06:20:00
# 1           1  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 07:00:00
# 2           2  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 07:30:00
# 3           3  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 08:00:00
# 4           4  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 08:30:00
#
#               end_date train_type  price train_class   fare
# 0  2019-05-29 09:16:00    AV City  38.55     Turista  Promo
# 1  2019-05-29 09:32:00        AVE  53.40     Turista  Promo
# 2  2019-05-29 09:51:00        AVE  47.30     Turista  Promo
# 3  2019-05-29 10:32:00        AVE  69.40  Preferente  Promo
# 4  2019-05-29 11:14:00      ALVIA    NaN     Turista  Promo

# %% [markdown]
# ### Show datatypes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579771 entries, 0 to 2579770
# Data columns (total 10 columns):
# Unnamed: 0     int64
# insert_date    object
# origin         object
# destination    object
# start_date     object
# end_date       object
# train_type     object
# price          float64
# train_class    object
# fare           object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 196.8+ MB

# %% [markdown]
# ### Check for null values

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# insert_date         0
# origin              0
# destination         0
# start_date          0
# end_date            0
# train_type          0
# price          310681
# train_class      9664
# fare             9664
# dtype: int64

# %% [markdown]
# ### Delete any rows with null values

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# Unnamed: 0     0
# insert_date    0
# origin         0
# destination    0
# start_date     0
# end_date       0
# train_type     0
# price          0
# train_class    0
# fare           0
# dtype: int64

# %% [markdown]
# ### Create a Series containing the Train Start Times

# %%
timeS = pd.Series(data["start_date"].str.split(" ").str[0].astype("datetime64"))
print(timeS[0:5])
# Out:
# 0   2019-05-29
# 1   2019-05-29
# 2   2019-05-29
# 3   2019-05-29
# 5   2019-05-29
# Name: start_date, dtype: datetime64[ns]

# %% [markdown]
# ### Number of Tickets purchased per Day

# %% [markdown]
# #### I realize now that this chart doesn't reveal any information to us, as the dates could have just been underreported

# %%
pd.value_counts(timeS).plot(figsize=(25,25))

# %%
plt.subplots(figsize=(10,5))
sns.countplot("destination", data=data, palette="rocket")
plt.show()
